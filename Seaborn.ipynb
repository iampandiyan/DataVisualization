# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('PreprocessedStudentsDataset.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.shape
# Out:
# (215, 15)

# %%
dataset.shape[0]
# Out:
# 215

# %%
dataset.shape[1]
# Out:
# 15

# %% [markdown]
# #Univariate Analysis
# It is used to print the frequecny. Histogram

# %%
import seaborn as sb
sb.distplot(dataset['ssc_p'])
# Out:
# C:\Users\Pandiyan\AppData\Local\Temp\ipykernel_26036\1707390150.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
#sb.violinplot(x="specialisation",y="salary",data=dataset,hue="gender")
#plt.yticks(ticks=range(0, int(dataset['salary'].max()) + 1, 5))

#plt.show()
#Explain more details extracted from the graph44

#import seaborn as sns
#import matplotlib.pyplot as plt

# Example data
#data = sns.load_dataset('PreprocessedStudentsDataset.csv')

# Create violin plot
#sns.violinplot(x="specialisation", y="salary", data=dataset)

# Manually set y-ticks to discrete values
#plt.yticks(ticks=range(0, int(dataset['salary'].max()) + 1, 5))  # Step of 5 for better readability

#plt.show()

# %%
sb.distplot(dataset['ssc_p'],hist=True)
# Out:
# C:\Users\Pandiyan\AppData\Local\Temp\ipykernel_26036\339838004.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'],hist=True)
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
sb.distplot(dataset['ssc_p'],hist=True,kde=True)
# Out:
# C:\Users\Pandiyan\AppData\Local\Temp\ipykernel_26036\3782099522.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'],hist=True,kde=True)
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
sb.distplot(dataset['ssc_p'],hist=True,kde=True, kde_kws={'color':'red'})
# Out:
# C:\Users\Pandiyan\AppData\Local\Temp\ipykernel_26036\2613818729.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'],hist=True,kde=True, kde_kws={'color':'red'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# #Bivarite Analyssis : Distributinoplot

# %% [markdown]
# #jointplot
# #Combination of scatterplot and Histogram

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset)

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset, kind='hex')

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset, kind='kde')

# %% [markdown]
# #Pairplot

# %%
sb.pairplot(dataset,hue='gender',diag_kind='kde',kind='scatter',palette='husl')

# %% [markdown]
# #For Catogorical plot

# %% [markdown]
# #stripplot

# %%
sb.stripplot(x='ssc_b',y='salary',data=dataset)
# Out:
# <Axes: xlabel='ssc_b', ylabel='salary'>

# %%
sb.stripplot(x='gender',y='salary',data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='salary'>

# %%
sb.stripplot(x='ssc_b',y='salary',data=dataset,jitter=True)
# Out:
# <Axes: xlabel='ssc_b', ylabel='salary'>

# %% [markdown]
# #swarmplot
#  It creates a categorical scatterplot where data points are adjusted along the categorical axis to avoid overlapping.
#  Non-overlapping points:
#  The points are jittered along the categorical axis to prevent overlapping, ensuring that the distribution of values is clear.
# Categorical grouping:
# The plot groups data points based on categories, allowing comparisons across groups.
# Combination with other plots:
# Swarmplots can be layered over boxplots, violin plots, or bar plots to provide detailed insights about the data distribution.

# %%
sb.swarmplot(x='ssc_b',y='salary',data=dataset)
# Out:
# <Axes: xlabel='ssc_b', ylabel='salary'>
# C:\Users\Pandiyan\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sb.swarmplot(x='ssc_b',y='salary',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='salary'>
# C:\Users\Pandiyan\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #Disitribution Observation

# %%
sb.violinplot(x='ssc_b',y='salary',data=dataset)
plt.show()

# %%
#print(dataset['salary'].min(), dataset['salary'].max())
print(dataset['salary'].describe())
# Out:
# count       215.000000
# mean     198702.325581
# std      154780.926716
# min           0.000000
# 25%           0.000000
# 50%      240000.000000
# 75%      282500.000000
# max      940000.000000
# Name: salary, dtype: float64

# %%
dataset['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         0.0
# Name: salary, Length: 215, dtype: float64

# %%
sb.violinplot(x='specialisation',y='salary',data=dataset)
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sb.violinplot(x="specialisation",y="salary",data=dataset,hue="gender")

plt.show()

# %% [markdown]
# #BoxPlot

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %% [markdown]
# #BarPlot

# %%
sb.barplot(x='ssc_b',y='ssc_p', data=dataset, hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %% [markdown]
# #Count Plot

# %%
sb.countplot(x='ssc_b', data=dataset, hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %% [markdown]
# #Pointplot

# %%
sb.pointplot(x='ssc_p',y='ssc_b', data=dataset, hue='gender')
# Out:
# <Axes: xlabel='ssc_p', ylabel='ssc_b'>

# %% [markdown]
# #BoxPlot

# %%
sb.boxplot(data=dataset,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# #Factor Plot is deprecated. Now it is replaced with catplot

# %%
excerciseDataset=sb.load_dataset('exercise')

excerciseDataset
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sb.catplot(x='time', y='pulse',hue='kind', kind='violin', col='diet', data=excerciseDataset)
plt.show()
#Density and box plot:

# %%
tipsDataset=sb.load_dataset('tips')
tipsDataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #Regplot

# %%
sb.regplot(x="total_bill",y="tip",data=tipsDataset)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #Lmplot

# %%
sb.lmplot(x="total_bill",y="tip",data=tipsDataset)

# %%
anscombeDataset=sb.load_dataset('anscombe')
anscombeDataset
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sb.lmplot(x='x',y='y',data=anscombeDataset.query("dataset == 'II'"))

# %%
sb.lmplot(x='x',y='y',data=anscombeDataset.query("dataset == 'II'"),order=2)

# %% [markdown]
# #FacetGrid

# %%
g=sb.FacetGrid(tipsDataset,col='time')
g.map(plt.hist,'tip')

# %% [markdown]
# #PairGrid

# %%
irisDataset=sb.load_dataset('iris')
irisDataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
g=sb.PairGrid(irisDataset)
g.map(plt.scatter)
